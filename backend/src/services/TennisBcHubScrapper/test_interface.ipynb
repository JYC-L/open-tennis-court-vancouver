# %%
# %conda list pandas
# %conda install -c conda-forge libgfortran numpy
# Out:
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

df = pd.read_json('all_availabilities.json')

result = []
for column in df.columns:
    result.append(df[column].unique())

result
# Out:
# [array(['Tennis BC Hub @ Richmond', 'Tennis BC Hub @ Stanley Park',
#         'UBC Tennis Center', 'UE Tennis'], dtype=object),
#  array(['Bubble Court 1', 'Bubble Court 2', 'Bubble Court 3',
#         'Bubble Court 4', 'Stanley Park Court #1', 'Stanley Park Court #2',
#         'Stanley Park Court #3', 'Stanley Park Court #4',
#         'Stanley Park Court #5', 'Stanley Park Court #6', 'court01',
#         'court02', 'court03', 'court04', 'court05', 'court06', 'court07',
#         'court08', 'court09', 'court10', 'court11', 'court12', 'court13',
#         'Court 1', 'Court 2', 'Court 3', 'Court 5'], dtype=object),
#  <DatetimeArray>
#  ['2025-06-20 00:00:00', '2025-06-22 00:00:00', '2025-06-23 00:00:00',
#   '2025-06-24 00:00:00', '2025-06-25 00:00:00', '2025-06-26 00:00:00',
#   '2025-06-27 00:00:00', '2025-06-28 00:00:00', '2025-06-29 00:00:00',
#   '2025-06-30 00:00:00', '2025-07-01 00:00:00', '2025-07-02 00:00:00',
#   '2025-06-21 00:00:00']
# ...

# %%
df.head()
# Out:
#                    clubName     courtNumber       date startHour startTime  \
# 0  Tennis BC Hub @ Richmond  Bubble Court 1 2025-06-20     08:00     08:30
# 1  Tennis BC Hub @ Richmond  Bubble Court 1 2025-06-20     14:00     14:30
# 2  Tennis BC Hub @ Richmond  Bubble Court 1 2025-06-22     07:00     07:30
# 3  Tennis BC Hub @ Richmond  Bubble Court 1 2025-06-22     21:00     21:00
# 4  Tennis BC Hub @ Richmond  Bubble Court 1 2025-06-23     06:00     06:30
#
#   endTime  bookable                                   courtBookingLink  \
# 0   09:00       0.0  https://clubspark.ca/TBCHubRichmond/Booking/bo...
# 1   15:30       0.0  https://clubspark.ca/TBCHubRichmond/Booking/bo...
# 2   08:00       0.0  https://clubspark.ca/TBCHubRichmond/Booking/bo...
# 3   22:00       0.0  https://clubspark.ca/TBCHubRichmond/Booking/bo...
# 4   08:00       0.0  https://clubspark.ca/TBCHubRichmond/Booking/bo...
#
#        location
# 0  Vancouver DT
# 1  Vancouver DT
# 2  Vancouver DT
# 3  Vancouver DT
# ...

# %%
print(df['date'].max())
print(df['date'].max()-df['date'].min())
# Out:
# 2025-07-02 00:00:00
# 12 days 00:00:00
