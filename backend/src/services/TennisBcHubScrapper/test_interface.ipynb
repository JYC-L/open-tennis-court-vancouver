# %%
# %conda list pandas
# %conda install -c conda-forge libgfortran numpy
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

df = pd.read_json('all_availabilities.json')

result = []
for column in df.columns:
    result.append(df[column].unique())

result
# Out:
# [array(['Tennis BC Hub @ Richmond', 'Tennis BC Hub @ Stanley Park',
#         'UBC Tennis Center', 'UE Tennis'], dtype=object),
#  array(['Bubble Court 1', 'Bubble Court 2', 'Bubble Court 3',
#         'Bubble Court 4', 'Stanley Park Court #1', 'Stanley Park Court #2',
#         'Stanley Park Court #3', 'Stanley Park Court #4',
#         'Stanley Park Court #5', 'Stanley Park Court #6', 'court01',
#         'court02', 'court03', 'court04', 'court05', 'court06', 'court07',
#         'court08', 'court09', 'court10', 'court11', 'court12', 'court13',
#         'Court 1', 'Court 2', 'Court 3', 'Court 5'], dtype=object),
#  <DatetimeArray>
#  ['2025-06-19 00:00:00', '2025-06-20 00:00:00', '2025-06-22 00:00:00',
#   '2025-06-23 00:00:00', '2025-06-24 00:00:00', '2025-06-25 00:00:00',
#   '2025-06-26 00:00:00', '2025-06-27 00:00:00', '2025-06-28 00:00:00',
#   '2025-06-29 00:00:00', '2025-06-30 00:00:00', '2025-07-01 00:00:00',
#   '2025-06-21 00:00:00']
#  Length: 13, dtype: datetime64[ns],
#  array(['06:00', '14:00', '22:00', '08:00', '15:00', '07:00', '19:00',
#         '13:00', '12:00', '10:00', '17:00', '09:00', '20:00', '11:00',
#         '16:00', '18:00', '21:00'], dtype=object),
#  array(['06:30', '14:30', '22:00', '08:30', '15:00', '07:30', '19:00',
#         '13:00', '12:00', '10:30', '13:30', '17:00', '14:00', '09:00',
#         '20:00', '09:30', '11:30', '16:00', '12:30', '08:00', '10:00',
#         '15:30', '17:30', '11:00', '20:30', '18:00', '18:30', '16:30',
#         '21:00', '09:15', '12:45', '15:15', '17:45', '20:15', '09:45',
#         '12:15', '14:45', '19:15', '11:45', '14:15', '16:45', '19:30',
#         '16:15', '20:45', '15:45', '18:15', '17:15', '19:45'], dtype=object),
#  array(['09:00', '15:00', '23:00', '16:00', '22:00', '08:00', '14:00',
#         '13:00', '07:30', '14:30', '18:00', '11:30', '10:00', '12:00',
#         '17:00', '07:00', '10:30', '08:30', '09:30', '12:30', '16:30',
#         '11:00', '21:00', '15:30', '19:00', '17:30', '20:00', '10:15',
#         '13:45', '16:15', '18:45', '21:15', '10:45', '13:15', '15:45',
#         '20:15', '21:30', '12:45', '15:15', '17:45', '20:30', '17:15',
#         '18:30', '21:45', '16:45', '19:15', '18:15', '19:30', '20:45'],
#        dtype=object),
#  array([  0.        , 179.22162639, 200.22162639, 223.22162639,
#         230.22162639, 233.72162639, 247.22162639, 177.72162611,
#         200.22162611, 223.22162611, 230.22162611, 233.72162611,
#         247.22162611, 177.72162583, 200.22162583, 223.22162583,
#         230.22162583, 233.72162583, 247.22162583, 175.22162556,
#         177.72162556, 181.72162556, 199.22162556, 201.72162556,
#         212.72162556, 223.22162556, 225.72162556, 236.72162556,
#         247.22162556, 249.72162556, 175.22162528, 185.72162528,
#         199.22162528, 201.72162528, 212.72162528, 223.22162528,
#         225.72162528, 236.72162528, 247.22162528, 249.72162528,
#         175.221625  , 177.721625  , 181.721625  , 199.221625  ,
#         201.721625  , 212.721625  , 223.221625  , 225.721625  ,
#         236.721625  , 247.221625  , 249.721625  , 182.221625  ,
#         187.721625  , 210.721625  , 182.22162472, 185.72162472,
#         199.22162472, 201.72162472, 210.72162472, 223.22162472,
#         225.72162472, 236.72162472, 247.22162472, 249.72162472,
#          24.        ]),
#  array(['https://clubspark.ca/TBCHubRichmond/Booking/bookbycourt#?startDate=2025-06-19&endDate=2025-06-26&resource=0&&role=guest',
#         'https://clubspark.ca/TBCHubRichmond/Booking/bookbycourt#?startDate=2025-06-19&endDate=2025-06-26&resource=1&&role=guest',
#         'https://clubspark.ca/TBCHubRichmond/Booking/bookbycourt#?startDate=2025-06-19&endDate=2025-06-26&resource=2&&role=guest',
#         'https://clubspark.ca/TBCHubRichmond/Booking/bookbycourt#?startDate=2025-06-19&endDate=2025-06-26&resource=3&&role=guest',
#         'https://clubspark.ca/TBCHubStanleyPark/Booking/bookbycourt#?startDate=2025-06-19&endDate=2025-06-26&resource=0&&role=guest',
#         'https://clubspark.ca/TBCHubStanleyPark/Booking/bookbycourt#?startDate=2025-06-19&endDate=2025-06-26&resource=1&&role=guest',
#         'https://clubspark.ca/TBCHubStanleyPark/Booking/bookbycourt#?startDate=2025-06-19&endDate=2025-06-26&resource=2&&role=guest',
#         'https://clubspark.ca/TBCHubStanleyPark/Booking/bookbycourt#?startDate=2025-06-19&endDate=2025-06-26&resource=3&&role=guest',
#         'https://clubspark.ca/TBCHubStanleyPark/Booking/bookbycourt#?startDate=2025-06-19&endDate=2025-06-26&resource=4&&role=guest',
#         'https://clubspark.ca/TBCHubStanleyPark/Booking/bookbycourt#?startDate=2025-06-19&endDate=2025-06-26&resource=5&&role=guest',
#         'https://ubc.perfectmind.com/24063/Clients/BookMe4LandingPages/Facility?facilityId=c0668c1c-1fd6-4432-a20e-4c50aaad5baa',
#         'https://ubc.perfectmind.com/24063/Clients/BookMe4LandingPages/Facility?facilityId=e2d99dda-cdc4-4af4-8df6-6c8061ffd56f',
#         'https://ubc.perfectmind.com/24063/Clients/BookMe4LandingPages/Facility?facilityId=c117a102-0ba0-4aa8-b8cf-eb8a1480be55',
#         'https://ubc.perfectmind.com/24063/Clients/BookMe4LandingPages/Facility?facilityId=47f78e62-2ac0-4d39-8ffa-5d331f60e14e',
#         'https://ubc.perfectmind.com/24063/Clients/BookMe4LandingPages/Facility?facilityId=e5432c07-c2a6-46d1-a5d7-25c58567046c',
#         'https://ubc.perfectmind.com/24063/Clients/BookMe4LandingPages/Facility?facilityId=f7000b6c-0d93-472b-97af-e0f22915439f',
#         'https://ubc.perfectmind.com/24063/Clients/BookMe4LandingPages/Facility?facilityId=5dac0879-1fbb-4dfe-ac67-5dcaa925d2f5',
#         'https://ubc.perfectmind.com/24063/Clients/BookMe4LandingPages/Facility?facilityId=ccbf3aa0-f263-44eb-b394-a603115f587a',
#         'https://ubc.perfectmind.com/24063/Clients/BookMe4LandingPages/Facility?facilityId=9f475d76-dbc1-463e-9097-210f31681e2f',
#         'https://ubc.perfectmind.com/24063/Clients/BookMe4LandingPages/Facility?facilityId=d5894b7a-2b61-4345-a1a8-ea8a50c921ae',
#         'https://ubc.perfectmind.com/24063/Clients/BookMe4LandingPages/Facility?facilityId=d3a55644-6681-42a7-b8f5-09d796d35c07',
#         'https://ubc.perfectmind.com/24063/Clients/BookMe4LandingPages/Facility?facilityId=00dc0e70-6536-4a5a-b60b-9f6b0d0ba050',
#         'https://ubc.perfectmind.com/24063/Clients/BookMe4LandingPages/Facility?facilityId=308fd9d5-0de2-442e-8bd7-3fa6b607d170',
#         'http://www.uetennis.com/booking-calendar/court-1?referral=service_list_widget',
#         'http://www.uetennis.com/booking-calendar/court-2?referral=service_list_widget',
#         'http://www.uetennis.com/booking-calendar/court-3?referral=service_list_widget',
#         'http://www.uetennis.com/booking-calendar/court-5?referral=service_list_widget'],
#        dtype=object),
#  array(['Vancouver DT', 'Richmond', 'UBC'], dtype=object)]

# %%
df.columns
# Out:
# Index(['clubName', 'courtNumber', 'date', 'startHour', 'startTime', 'endTime',
#        'bookable', 'courtBookingLink', 'location'],
#       dtype='object')
